# %%
print('hello')
# Out:
# hello

# %%
a=1
b=2
c=a+b
d=a-b
e=a*b
f=a//b
g=a/b
print("addition is ",c,"subtraction is ",d,"multiplication is ",e,"floor division is ",f,"division is",g)
# Out:
# addition is  3 subtraction is  -1 multiplication is  2 floor division is  0 division is 0.5

# %%
a=10
b=20
a>b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
a>=b
# Out:
# False

# %%
a**b
# Out:
# 100000000000000000000

# %%
a>>b
# Out:
# 0

# %%
a<<b
# Out:
# 10485760
